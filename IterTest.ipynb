# %%
from SMA_IT import IterativeBacktest as IB

# %%
ib = IB(units=9)

# %%
#ib.update_current_df()

# %%
ib.init_initial_balance()
#ib.update_current_df()

# %%
ib.initial_balance
# Out:
# 606.87

# %%
ib.test_macd_strategy_bracket(12, 26, 9)
# Out:
# ---------------------------------------------------------------------------
# Testing MACD strategy | None | EMA_S = 12 & EMA_S = 12
# ---------------------------------------------------------------------------
# 2021-08-12 16:35:00 |  Buying 9 for 612.54
# 2021-08-12 16:45:00 |  Selling 9 for 608.76
# 2021-08-12 16:55:00 |  Buying 9 for 611.64
# 2021-08-12 18:15:00 |  Selling 9 for 612.54
# 2021-08-12 19:55:00 |  Buying 9 for 608.4
# C:\Users\GP4EYN2\EFS-PROJECTS\eclipse-workspaces\crypto_ws\eclipse_project\SMA_IT.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.cur_df["EMA_S"] = self.cur_df["Close"].ewm(span = self.EMA_S, min_periods = self.EMA_S).mean()
# ...

# %%
date = str(ib.df.index[10])

# %%
date
# Out:
# '2021-08-10 16:20:00'
